# %%
# !git clone https://github.com/osafty/ColorDeblurring.git

# %%
import os
os.getcwd()

# %%
os.chdir('/content/ColorDeblurring/second_implementation/deblurring')

# %%
# !pip install virtualenv

# %%
# !virtualenv venv -p python3

# %%
# !. venv/bin/activate

# %%
! pip install -r requirements/requirements.txt

# %%
! pip install -e .

# %%
# !pip install keras==2.1.5 tensorflow==1.5

# %%
os.chdir('/content/ColorDeblurring/second_implementation')
os.mkdir('image_deblur_res')
os.mkdir('image_col_res')
os.chdir('/content/ColorDeblurring/second_implementation/deblurring')

# %%
#os.rmdir('/content/ColorDeblurring/second_implementation/deblurring/images/train')
#!rm -r /content/ColorDeblurring/second_implementation/deblurring/GOPRO_Large/train/.ipynb_checkpoints
#!rm -r /content/ColorDeblurring/second_implementation/deblurring/weights/65
#!rm -r /content/ColorDeblurring/second_implementation/deblurring/scripts/train.py
#!rm -r /content/ColorDeblurring/second_implementation/deblurring/GOPRO_Large/test/GOPRO372/blur
#!rm -r /content/ColorDeblurring/second_implementation/deblurring/GOPRO_Large/test/GOPRO372/sharp
#os.mkdir('./GOPRO_Large/test/GOPRO372/blur')
#os.mkdir('./GOPRO_Large/test/GOPRO372/sharp')

# %%
# !python ./scripts/organize_gopro_dataset.py --dir_in=GOPRO_Large --dir_out=images

# %%
#!python ./scripts/train.py --help

# %%
# !python ./scripts/train.py --n_images=300 --batch_size=2 --log_dir /content/ColorDeblurring/second_implementation/deblurring/venv

# %%
# !python ./scripts/test_accuracy.py

# %%
#! python ./scripts/deblur_image.py --weight_path=/content/ColorDeblurring/second_implementation/deblurring/weights/66/generator_3_2348.h5 --input_dir=/content/ColorDeblurring/second_implementation/image_sample --output_dir=/content/ColorDeblurring/second_implementation/image_deblur_res
! python ./scripts/deblur_image.py --weight_path=generator.h5 --input_dir=/content/ColorDeblurring/second_implementation/image_sample --output_dir=/content/ColorDeblurring/second_implementation/image_deblur_res

# %%
#!zip -r /content/ColorDeblurring/second_implementation/image_deblur_res.zip /content/ColorDeblurring/second_implementation/image_deblur_res
#from google.colab import files
#files.download("/content/ColorDeblurring/second_implementation/image_deblur_res")

# %%
os.chdir('/content/ColorDeblurring/second_implementation/colorization')

# %%
# !chmod u+rwx ./models/fetch_release_models.sh
# !./models/fetch_release_models.sh

# %%
# !apt install -y caffe-cuda

# %%
# !pip install scikit-image==0.11.3

# %%
os.getcwd()

# %%
# !chmod u+rwx ./colorize.py

# %%
# !./colorize.py -img_in /content/ColorDeblurring/second_implementation/image_deblur_res/rdeer.jpg -img_out /content/ColorDeblurring/second_implementation/image_col_res/rdeer.jpg

# %%
#!./colorize.py -img_in /content/ColorDeblurring/second_implementation/image_deblur_res/24_HUAWEI-Y9_M_gs.jpg -img_out /content/ColorDeblurring/second_implementation/image_col_res/24_HUAWEI-Y9_M_gs.jpg
#!./colorize.py -img_in /content/ColorDeblurring/second_implementation/image_deblur_res/21_HUAWEI-Y9_M_gs.jpg -img_out /content/ColorDeblurring/second_implementation/image_col_res/21_HUAWEI-Y9_M_gs.jpg
#!./colorize.py -img_in /content/ColorDeblurring/second_implementation/image_deblur_res/21_HUAWEI-Y9_F.jpg -img_out /content/ColorDeblurring/second_implementation/image_col_res/21_HUAWEI-Y9_F.jpg
#!./colorize.py -img_in /content/ColorDeblurring/second_implementation/image_deblur_res/1_XIAOMI-PROCOFONE-F1_M_gs.jpg -img_out /content/ColorDeblurring/second_implementation/image_col_res/1_XIAOMI-PROCOFONE-F1_M_gs.jpg

# %%
#!zip -r /content/ColorDeblurring/second_implementation/image_col_res.zip /content/ColorDeblurring/second_implementation/image_col_res

# %%
#!rm -r /content/ColorDeblurring/second_implementation/image_deblur_res
#!rm -r /content/ColorDeblurring/second_implementation/image_col_res
#os.chdir('/content/ColorDeblurring/second_implementation')
#os.mkdir('image_deblur_res')
#os.mkdir('image_col_res')
#os.chdir('/content/ColorDeblurring/second_implementation/colorization')
